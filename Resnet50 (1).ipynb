# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, MaxPooling2D, GlobalAveragePooling2D, Dense, Add
from tensorflow.keras.models import Model

def residual_block(x, filters, kernel_size=3, stride=1):
    shortcut = x
    x = Conv2D(filters, kernel_size, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv2D(filters, kernel_size, padding='same')(x)
    x = BatchNormalization()(x)

    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = Conv2D(filters, 1, strides=stride)(shortcut)
        shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

def ResNet50(input_shape=(224, 224, 3), num_classes=1000):
    inputs = Input(shape=input_shape)

    x = Conv2D(64, 7, strides=2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPooling2D(pool_size=3, strides=2, padding='same')(x)

    x = residual_block(x, 64, stride=1)
    x = residual_block(x, 64, stride=1)
    x = residual_block(x, 64, stride=1)

    x = residual_block(x, 128, stride=2)
    x = residual_block(x, 128, stride=1)
    x = residual_block(x, 128, stride=1)
    x = residual_block(x, 128, stride=1)

    x = residual_block(x, 256, stride=2)
    x = residual_block(x, 256, stride=1)
    x = residual_block(x, 256, stride=1)
    x = residual_block(x, 256, stride=1)
    x = residual_block(x, 256, stride=1)
    x = residual_block(x, 256, stride=1)

    x = residual_block(x, 512, stride=2)
    x = residual_block(x, 512, stride=1)
    x = residual_block(x, 512, stride=1)

    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Example usage:
model = ResNet50()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 112, 112, 64)         9472      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 112, 112, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 112, 112, 64)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 64)           0         ['re_lu[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 64)           36928     ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 56, 56, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 56, 56, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)           36928     ['re_lu_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 56, 56, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 56, 56, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     , 'max_pooling2d[0][0]']
#
#  re_lu_2 (ReLU)              (None, 56, 56, 64)           0         ['add[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 64)           36928     ['re_lu_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 56, 56, 64)           256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 56, 56, 64)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 64)           36928     ['re_lu_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 56, 56, 64)           256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 56, 56, 64)           0         ['batch_normalization_4[0][0]'
#                                                                     , 're_lu_2[0][0]']
#
#  re_lu_4 (ReLU)              (None, 56, 56, 64)           0         ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 64)           36928     ['re_lu_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 56, 56, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 56, 56, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 64)           36928     ['re_lu_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 56, 56, 64)           256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 56, 56, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     , 're_lu_4[0][0]']
#
#  re_lu_6 (ReLU)              (None, 56, 56, 64)           0         ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 128)          73856     ['re_lu_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 28, 28, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 28, 28, 128)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 128)          147584    ['re_lu_7[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 128)          8320      ['re_lu_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 28, 28, 128)          512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 28, 28, 128)          512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 28, 28, 128)          0         ['batch_normalization_8[0][0]'
#                                                                     , 'batch_normalization_9[0][0]
#                                                                     ']
#
#  re_lu_8 (ReLU)              (None, 28, 28, 128)          0         ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 128)          147584    ['re_lu_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 28, 28, 128)          512       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  re_lu_9 (ReLU)              (None, 28, 28, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 128)          147584    ['re_lu_9[0][0]']
#
#  batch_normalization_11 (Ba  (None, 28, 28, 128)          512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 28, 28, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      're_lu_8[0][0]']
#
#  re_lu_10 (ReLU)             (None, 28, 28, 128)          0         ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 128)          147584    ['re_lu_10[0][0]']
#
#  batch_normalization_12 (Ba  (None, 28, 28, 128)          512       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 128)          147584    ['re_lu_11[0][0]']
#
#  batch_normalization_13 (Ba  (None, 28, 28, 128)          512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 28, 28, 128)          0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      're_lu_10[0][0]']
#
#  re_lu_12 (ReLU)             (None, 28, 28, 128)          0         ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 128)          147584    ['re_lu_12[0][0]']
#
#  batch_normalization_14 (Ba  (None, 28, 28, 128)          512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 128)          147584    ['re_lu_13[0][0]']
#
#  batch_normalization_15 (Ba  (None, 28, 28, 128)          512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 28, 28, 128)          0         ['batch_normalization_15[0][0]
#                                                                     ',
#                                                                      're_lu_12[0][0]']
#
#  re_lu_14 (ReLU)             (None, 28, 28, 128)          0         ['add_6[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 256)          295168    ['re_lu_14[0][0]']
#
#  batch_normalization_16 (Ba  (None, 14, 14, 256)          1024      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_15[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 256)          33024     ['re_lu_14[0][0]']
#
#  batch_normalization_17 (Ba  (None, 14, 14, 256)          1024      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 14, 14, 256)          1024      ['conv2d_18[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 14, 14, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ',
#                                                                      'batch_normalization_18[0][0]
#                                                                     ']
#
#  re_lu_16 (ReLU)             (None, 14, 14, 256)          0         ['add_7[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_16[0][0]']
#
#  batch_normalization_19 (Ba  (None, 14, 14, 256)          1024      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  re_lu_17 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_17[0][0]']
#
#  batch_normalization_20 (Ba  (None, 14, 14, 256)          1024      ['conv2d_20[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 14, 14, 256)          0         ['batch_normalization_20[0][0]
#                                                                     ',
#                                                                      're_lu_16[0][0]']
#
#  re_lu_18 (ReLU)             (None, 14, 14, 256)          0         ['add_8[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_18[0][0]']
#
#  batch_normalization_21 (Ba  (None, 14, 14, 256)          1024      ['conv2d_21[0][0]']
#  tchNormalization)
#
#  re_lu_19 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_19[0][0]']
#
#  batch_normalization_22 (Ba  (None, 14, 14, 256)          1024      ['conv2d_22[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 14, 14, 256)          0         ['batch_normalization_22[0][0]
#                                                                     ',
#                                                                      're_lu_18[0][0]']
#
#  re_lu_20 (ReLU)             (None, 14, 14, 256)          0         ['add_9[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_20[0][0]']
#
#  batch_normalization_23 (Ba  (None, 14, 14, 256)          1024      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  re_lu_21 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_21[0][0]']
#
#  batch_normalization_24 (Ba  (None, 14, 14, 256)          1024      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 14, 14, 256)          0         ['batch_normalization_24[0][0]
#                                                                     ',
#                                                                      're_lu_20[0][0]']
#
#  re_lu_22 (ReLU)             (None, 14, 14, 256)          0         ['add_10[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_22[0][0]']
#
#  batch_normalization_25 (Ba  (None, 14, 14, 256)          1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  re_lu_23 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_23[0][0]']
#
#  batch_normalization_26 (Ba  (None, 14, 14, 256)          1024      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 14, 14, 256)          0         ['batch_normalization_26[0][0]
#                                                                     ',
#                                                                      're_lu_22[0][0]']
#
#  re_lu_24 (ReLU)             (None, 14, 14, 256)          0         ['add_11[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_24[0][0]']
#
#  batch_normalization_27 (Ba  (None, 14, 14, 256)          1024      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  re_lu_25 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_25[0][0]']
#
#  batch_normalization_28 (Ba  (None, 14, 14, 256)          1024      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 14, 14, 256)          0         ['batch_normalization_28[0][0]
#                                                                     ',
#                                                                      're_lu_24[0][0]']
#
#  re_lu_26 (ReLU)             (None, 14, 14, 256)          0         ['add_12[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 7, 7, 512)            1180160   ['re_lu_26[0][0]']
#
#  batch_normalization_29 (Ba  (None, 7, 7, 512)            2048      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  re_lu_27 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 7, 7, 512)            2359808   ['re_lu_27[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 7, 7, 512)            131584    ['re_lu_26[0][0]']
#
#  batch_normalization_30 (Ba  (None, 7, 7, 512)            2048      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 7, 7, 512)            2048      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 7, 7, 512)            0         ['batch_normalization_30[0][0]
#                                                                     ',
#                                                                      'batch_normalization_31[0][0]
#                                                                     ']
#
#  re_lu_28 (ReLU)             (None, 7, 7, 512)            0         ['add_13[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 7, 7, 512)            2359808   ['re_lu_28[0][0]']
#
#  batch_normalization_32 (Ba  (None, 7, 7, 512)            2048      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  re_lu_29 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 7, 7, 512)            2359808   ['re_lu_29[0][0]']
#
#  batch_normalization_33 (Ba  (None, 7, 7, 512)            2048      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 7, 7, 512)            0         ['batch_normalization_33[0][0]
#                                                                     ',
#                                                                      're_lu_28[0][0]']
#
#  re_lu_30 (ReLU)             (None, 7, 7, 512)            0         ['add_14[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 7, 7, 512)            2359808   ['re_lu_30[0][0]']
#
#  batch_normalization_34 (Ba  (None, 7, 7, 512)            2048      ['conv2d_34[0][0]']
#  tchNormalization)
#
#  re_lu_31 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 7, 7, 512)            2359808   ['re_lu_31[0][0]']
#
#  batch_normalization_35 (Ba  (None, 7, 7, 512)            2048      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 7, 7, 512)            0         ['batch_normalization_35[0][0]
#                                                                     ',
#                                                                      're_lu_30[0][0]']
#
#  re_lu_32 (ReLU)             (None, 7, 7, 512)            0         ['add_15[0][0]']
#
#  global_average_pooling2d (  (None, 512)                  0         ['re_lu_32[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1000)                 513000    ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 21823208 (83.25 MB)
# Trainable params: 21806184 (83.18 MB)
# Non-trainable params: 17024 (66.50 KB)
# __________________________________________________________________________________________________
